# %%
import pandas as pd
import numpy as np

# %%
read = pd.read_excel('Dry_Bean_Dataset.xlsx')
data = {}
read.sort_values(['Class'], inplace=True)
read.reset_index(inplace=True)
# Out:
#        index   Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# 0       2496  66107   1108.565       367.616595       230.636709
# 1       2635  68676   1082.871       373.711626       235.159092
# 2       2636  68725   1130.424       371.809349       236.308153
# 3       2637  68732   1029.691       359.009355       244.455780
# 4       2638  68764   1045.125       354.689008       247.500826
# ...      ...    ...        ...              ...              ...
# 13606   8444  43255    787.245       297.692795       185.431674
# 13607   8445  43255    775.342       295.942758       186.439467
# 13608   8446  43261    790.347       296.501721       186.216598
# 13609   8439  43233    784.198       297.147044       186.689074
# 13610   7631  38396    732.799       269.942588       181.735599
#
#        AspectRation  Eccentricity  ConvexArea  EquivDiameter    Extent  \
# 0          1.593921      0.778710       67763     290.120745  0.699353
# ...

# %%
read.isnull().values.any()
read.drop(columns=['index'], inplace=True)
X = list(read['Class'].unique())
# Out:
# ['BARBUNYA', 'BOMBAY', 'CALI', 'DERMASON', 'HOROZ', 'SEKER', 'SIRA']

# %%
feature = read.drop(columns=['Class'])
feature_names = list(feature.columns)
data['feature_names'] = feature_names
# Out:
# {'feature_names': ['Area',
#   'Perimeter',
#   'MajorAxisLength',
#   'MinorAxisLength',
#   'AspectRation',
#   'Eccentricity',
#   'ConvexArea',
#   'EquivDiameter',
#   'Extent',
#   'Solidity',
#   'roundness',
#   'Compactness',
#   'ShapeFactor1',
#   'ShapeFactor2',
#   'ShapeFactor3',
#   'ShapeFactor4']}

# %%
classes = list(read['Class'].unique())

data['target_names'] = np.array(classes)
target = []
for i in list(read['Class']):
    if i is X[0]:
        y = 0
        target.append(y)
    elif i is X[1]:
        y = 1
        target.append(y)
    elif i is X[2]:
        y = 2
        target.append(y)
    elif i is X[3]:
        y = 3
        target.append(y)
    elif i is X[4]:
        y = 4
        target.append(y)
    elif i is X[5]:
        y = 5
        target.append(y)
    elif i is X[6]:
        y = 6
        target.append(y)
data['target'] = np.array(target)
# Out:
# {'feature_names': ['Area',
#   'Perimeter',
#   'MajorAxisLength',
#   'MinorAxisLength',
#   'AspectRation',
#   'Eccentricity',
#   'ConvexArea',
#   'EquivDiameter',
#   'Extent',
#   'Solidity',
#   'roundness',
#   'Compactness',
#   'ShapeFactor1',
#   'ShapeFactor2',
#   'ShapeFactor3',
#   'ShapeFactor4'],
#  'target_names': array(['BARBUNYA', 'BOMBAY', 'CALI', 'DERMASON', 'HOROZ', 'SEKER', 'SIRA'],
#        dtype='<U8'),
#  'target': array([0, 0, 0, ..., 6, 6, 6])}

# %%
arr = np.array(feature)
data['data'] = arr
# Out:
# {'feature_names': ['Area',
#   'Perimeter',
#   'MajorAxisLength',
#   'MinorAxisLength',
#   'AspectRation',
#   'Eccentricity',
#   'ConvexArea',
#   'EquivDiameter',
#   'Extent',
#   'Solidity',
#   'roundness',
#   'Compactness',
#   'ShapeFactor1',
#   'ShapeFactor2',
#   'ShapeFactor3',
#   'ShapeFactor4'],
#  'target_names': array(['BARBUNYA', 'BOMBAY', 'CALI', 'DERMASON', 'HOROZ', 'SEKER', 'SIRA'],
#        dtype='<U8'),
#  'target': array([0, 0, 0, ..., 6, 6, 6]),
#  'data': array([[6.61070000e+04, 1.10856500e+03, 3.67616595e+02, ...,
#          1.33064475e-03, 6.22826885e-01, 9.92736584e-01],
#         [6.86760000e+04, 1.08287100e+03, 3.73711626e+02, ...,
#          1.31581600e-03, 6.26097388e-01, 9.94985442e-01],
#         [6.87250000e+04, 1.13042400e+03, 3.71809349e+02, ...,
#          1.33706903e-03, 6.32971645e-01, 9.95923214e-01],
#         ...,
#         [4.32610000e+04, 7.90347000e+02, 2.96501721e+02, ...,
#          1.65964383e-03, 6.26544951e-01, 9.97610624e-01],
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
X_train, X_test, y_train, y_test = train_test_split(data['data'], data['target'], random_state=42)
scaler = MinMaxScaler()
scaler.fit(X_train)
x_train = scaler.transform(X_train)
x_test = scaler.transform(X_test)

# %%
algo = [SVC, GradientBoostingClassifier, RandomForestClassifier]
for i in algo:
    if i is SVC:
        classifier = i()
        classifier.fit(x_train, y_train)
        print(f'{i.__name__} train score : {classifier.score(x_train, y_train)}')
        print(f'{i.__name__} test score : {classifier.score(x_test, y_test)}')
    else:
        classifier = i(random_state=0)
        classifier.fit(x_train, y_train)
        print(f'{i.__name__} train score : {classifier.score(x_train, y_train)}')
        print(f'{i.__name__} test score : {classifier.score(x_test, y_test)}')
# Out:
# SVC train score : 0.9244710031347962
# SVC test score : 0.9274169850132237
# GradientBoostingClassifier train score : 0.9627742946708464
# GradientBoostingClassifier test score : 0.9250661181310609
# RandomForestClassifier train score : 1.0
# RandomForestClassifier test score : 0.926829268292683
