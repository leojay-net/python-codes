# %%
import pandas as pd
import numpy as np
import re
def answer_one():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    return Energy
answer_one()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-fa16375bff7c> in <module>
#      16     Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country')
#      17     return Energy
# ---> 18 answer_one()
#
# <ipython-input-1-fa16375bff7c> in answer_one()
#       3 import re
#       4 def answer_one():
# ----> 5     re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
#       6     Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
#       7     Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# ...

# %%
import pandas as pd
import numpy as np
def answer_two():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='outer', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='outer', left_index=True, right_index=True).sort_values('Rank')
    
    merged3 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged4 = pd.merge(ScimEn, merged3, how='inner', left_index=True, right_index=True).sort_values('Rank')
    return len(merged2)-len(merged4)
    raise NotImplementedError()
answer_two()

# %%
import pandas as pd
import numpy as np
def answer_three():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank')
    merged3 = merged2.drop(merged2.columns[0:10], axis=1)
    avgGDP = merged3.groupby('Country').apply(np.nanmean)
    return avgGDP.sort_values(ascending=False)
    raise NotImplementedError()
answer_three()

# %%
import pandas as pd
import numpy as np
def answer_four():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank')
    merged3 = merged2.drop(merged2.columns[0:10], axis=1)
    diff = merged3.loc['United Kingdom']['2015']-merged3.loc['United Kingdom']['2006']
    return diff
answer_four()

# %%
def answer_five():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank')
    return merged2['Energy Supply per Capita'].mean()
answer_five()

# %%
def answer_six():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank')
    return (merged2['% Renewable'].idxmax(), merged2['% Renewable'].max())
answer_six()

# %%
def answer_seven():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank')
    merged2['Ratio'] = (merged2['Self-citations']/merged2['Citations'])
    return (merged2['Ratio'].idxmax(), merged2['Ratio'].max())
answer_seven()

# %%
def answer_eight():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank')
    merged2['Est. Population'] = (merged2['Energy Supply']/merged2['Energy Supply per Capita'])
    merged2.sort_values('Est. Population', ascending=False, inplace=True)
    return merged2.index[2]
answer_eight()

# %%
def answer_nine():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank')
    merged2['Est. Population'] = (merged2['Energy Supply']/merged2['Energy Supply per Capita'])
    merged2.sort_values('Est. Population', ascending=False, inplace=True)
    merged2['Citable docs per Capita'] = merged2['Citable documents']/merged2['Est. Population']
    p_corr = merged2['Citable docs per Capita'].corr(merged2['Energy Supply per Capita'])
    return p_corr
answer_nine()

# %%
def answer_ten():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank')
    merged2['Est. Population'] = (merged2['Energy Supply']/merged2['Energy Supply per Capita'])
    merged2.sort_values('Est. Population', ascending=False, inplace=True)
    merged2['Citable docs per Capita'] = merged2['Citable documents']/merged2['Est. Population']
    p_corr = merged2['Citable docs per Capita'].corr(merged2['Energy Supply per Capita'])
    middle = merged2['% Renewable'].median()
    merged2['Mid % Renewable']=merged2['% Renewable']
    merged2['Mid % Renewable']=np.where(merged2['Mid % Renewable']<middle,0,1)
    merged2 = merged2.sort_values('Rank')
    HighRenew = merged2['Mid % Renewable']
    return HighRenew
answer_ten()

# %%
def answer_eleven():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank').reset_index()
    merged2['Est. Population'] = (merged2['Energy Supply']/merged2['Energy Supply per Capita'])
    merged2.sort_values('Est. Population', ascending=False, inplace=True)
    merged2['Continent'] = merged2['Country']
    con = merged2['Continent'].replace({'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}, inplace=True)
    new_df = merged2.groupby('Continent').agg({'Est. Population': ['size', np.sum, np.mean, np.std]})
    new_df.columns = ['_'.join(col) for col in new_df.columns.to_flat_index()]
    new_df.rename(columns={
        'Est. Population_size':'size', 'Est. Population_sum':'sum', 'Est. Population_mean':'mean',
       'Est. Population_std':'std'
        }, inplace=True)
    return new_df
    raise NotImplementedError()
answer_eleven()

# %%
def answer_twelve():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank').reset_index()
    merged2['Est. Population'] = (merged2['Energy Supply']/merged2['Energy Supply per Capita'])
    merged2.sort_values('Est. Population', ascending=False, inplace=True)
    merged2['bins'] = pd.cut(merged2['% Renewable'], 5)
    merged2['Continent'] = merged2['Country']
    merged2['Continent'].replace({'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}, inplace=True)
    new_df = merged2.groupby(['Continent','bins']).agg('size')
    new_df.rename_axis(index={'bins':'% Renewable'}, inplace=True)
    return new_df
    raise NotImplementedError()
answer_twelve()

# %%
def answer_thirteen():
    re = pd.read_excel('assets/Energy Indicators.xls', header=17, skipfooter=38)
    Energy = pd.DataFrame(re).rename(columns={'Unnamed: 2':'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})
    Energy.drop(['Unnamed: 0','Unnamed: 1'], axis=1, inplace=True)
    df = Energy['Energy Supply'].apply(lambda x:1000000*x)
    Energy['Energy Supply']=df
    Energy =  Energy.replace({'\.+': np.nan,
                             "Republic of Korea": "South Korea",
                             "United States of America": "United States",
                             "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                             "China, Hong Kong Special Administrative Region": "Hong Kong"
                             }, regex=True)
    Energy = Energy.replace('[0-9]+|\s\([\w\s]*\)','', regex=True).set_index('Country') 
    GDP = pd.read_csv('assets/world_bank.csv', header=4)
    GDP = GDP.replace({
        "Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"
    }).drop(GDP.columns[1:50], axis=1).rename(columns={'Country Name':'Country'}).set_index('Country')
    re2 = pd.read_excel('assets/scimagojr-3.xlsx')
    ScimEn = re2.iloc[:16].set_index('Country')
    merged1 = pd.merge(Energy, GDP, how='inner', left_index=True, right_index=True)
    merged2 = pd.merge(ScimEn, merged1, how='inner', left_index=True, right_index=True).sort_values('Rank')
    merged2['Est. Population'] = (merged2['Energy Supply']/merged2['Energy Supply per Capita'])
    new_sr = merged2['Est. Population'].map('{:,}'.format)
    return new_sr
    raise NotImplementedError()
answer_thirteen()
